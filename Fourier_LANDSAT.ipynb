# %%
# !pip install statsmodels --upgrade
# Out:
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (0.10.2)
# Collecting statsmodels
#   Downloading statsmodels-0.13.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.8 MB)
#      |████████████████████████████████| 9.8 MB 5.3 MB/s
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (21.3)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.4.1)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.21.6)
# Requirement already satisfied: pandas>=0.25 in /usr/local/lib/python3.7/dist-packages (from statsmodels) (1.3.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->statsmodels) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->statsmodels) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5.2->statsmodels) (1.15.0)
# Installing collected packages: statsmodels
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.10.2
#     Uninstalling statsmodels-0.10.2:
#       Successfully uninstalled statsmodels-0.10.2
# Successfully installed statsmodels-0.13.2

# %%
# !pip install statsmodels==0.12.1
# Out:
# Collecting statsmodels==0.12.1
#   Downloading statsmodels-0.12.1-cp37-cp37m-manylinux1_x86_64.whl (9.5 MB)
#      |████████████████████████████████| 9.5 MB 4.5 MB/s
# Requirement already satisfied: patsy>=0.5 in /usr/local/lib/python3.7/dist-packages (from statsmodels==0.12.1) (0.5.2)
# Requirement already satisfied: pandas>=0.21 in /usr/local/lib/python3.7/dist-packages (from statsmodels==0.12.1) (1.3.5)
# Requirement already satisfied: scipy>=1.1 in /usr/local/lib/python3.7/dist-packages (from statsmodels==0.12.1) (1.4.1)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from statsmodels==0.12.1) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->statsmodels==0.12.1) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.21->statsmodels==0.12.1) (2022.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.5->statsmodels==0.12.1) (1.15.0)
# Installing collected packages: statsmodels
#   Attempting uninstall: statsmodels
#     Found existing installation: statsmodels 0.13.2
#     Uninstalling statsmodels-0.13.2:
#       Successfully uninstalled statsmodels-0.13.2
# Successfully installed statsmodels-0.12.1

# %%
import pandas as pd
import io
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-602af679-846b-4d0a-87e6-c07e8f5b77bc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-602af679-846b-4d0a-87e6-c07e8f5b77bc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving bas_land_16d_84-22.csv to bas_land_16d_84-22 (1).csv
# Saving gob_land_16d_84-22.csv to gob_land_16d_84-22.csv
# Saving roi_land_16d_84-22.csv to roi_land_16d_84-22 (1).csv
# Saving zin_land_16d_84-22.csv to zin_land_16d_84-22.csv

# %%
#df = pd.read_csv(io.BytesIO(uploaded['bas_land_16d_84-22.csv']))
#df = pd.read_csv(io.BytesIO(uploaded['gob_land_16d_84-22.csv']))
df = pd.read_csv(io.BytesIO(uploaded['roi_land_16d_84-22.csv']))
#df = pd.read_csv(io.BytesIO(uploaded['zin_land_16d_84-22.csv']), parse_dates=["date"], dayfirst=True)

# %%
#for bastrow and zin its 36 years. (828)
#for namibia its 35 years. (805)

# %%
df= df.rename(columns={'NDVI_S': 'NDVI'})
#df['date'] = pd.to_datetime(df['date'])
#df = df.set_index('date', drop = False)
TimeSeries_LST2 =  list(df['NDVI'])   
TimeSeries_DATE2 = list(df['date'])
df.head()
# Out:
#          date   NDVI
# 0  1984-09-09  0.078
# 1  1984-09-25  0.082
# 2  1984-10-11  0.086
# 3  1984-10-27  0.066
# 4  1984-11-12  0.071

# %%
'''
k=1
while len(TimeSeries_LST2) < 828:
  TimeSeries_LST2.append(0.099899999999998)
  TimeSeries_DATE2.append(str(k)+'-12-2021')
  k+=1
  NDVI = TimeSeries_LST2
time= TimeSeries_DATE2
df = pd.DataFrame({'date' : time, 'NDVI' : NDVI})
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date') 
print(len(df['NDVI']))
'''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-156-9b47464eba13> in <module>()
#       6   NDVI = TimeSeries_LST2
#       7 time= TimeSeries_DATE2
# ----> 8 df = pd.DataFrame({'date' : time, 'NDVI' : NDVI})
#       9 df['date'] = pd.to_datetime(df['date'])
#      10 df = df.set_index('date')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     612         elif isinstance(data, dict):
#     613             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 614             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     615         elif isinstance(data, ma.MaskedArray):
#     616             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     463
#     464     return arrays_to_mgr(
# --> 465         arrays, data_names, index, columns, dtype=dtype, typ=typ, consolidate=copy
#     466     )
#     467
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity, typ, consolidate)
#     117         # figure out the index, if necessary
#     118         if index is None:
# --> 119             index = _extract_index(arrays)
#     120         else:
#     121             index = ensure_index(index)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/construction.py in _extract_index(data)
#     633             lengths = list(set(raw_lengths))
#     634             if len(lengths) > 1:
# --> 635                 raise ValueError("All arrays must be of the same length")
#     636
#     637             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
TimeSeries = []
TimeSeries_DATE=[]
k=1
c = 805 - len(TimeSeries_LST2)
while c>0:
  TimeSeries.append(0.099899999999998)
  TimeSeries_DATE.append(str(k)+'-1-2022')
  k+=1
  c-=1


time= TimeSeries_DATE
df1 = pd.DataFrame({'date' : time, 'NDVI' : TimeSeries})
df1['date'] = pd.to_datetime(df1['date'])
df1 = df1.set_index('date',drop = False)
df = df.set_index('date',drop = False)

# %%
#for namibia only this code
while len(TimeSeries_LST2) > 782:
  l = len(TimeSeries_LST2)
  TimeSeries_LST2.pop(-1)
  TimeSeries_DATE2.pop(-1)

NDVI = TimeSeries_LST2
time= TimeSeries_DATE2
df = pd.DataFrame({'date' : time, 'NDVI' : NDVI})
df['date'] = pd.to_datetime(df['date'])
df = df.set_index('date') 
print(len(df['NDVI']))
# Out:
# 782

# %%
df1.head()
# Out:
#                  date    NDVI
# date
# 2022-01-01 2022-01-01  0.0999
# 2022-02-01 2022-02-01  0.0999
# 2022-03-01 2022-03-01  0.0999
# 2022-04-01 2022-04-01  0.0999
# 2022-05-01 2022-05-01  0.0999

# %%
df = pd.concat([df, df1], ignore_index=True)
print(len(df))
# Out:
# 802

# %%
df.tail()
# Out:
#                     date    NDVI
# 800  2022-01-16 00:00:00  0.0999
# 801  2022-01-17 00:00:00  0.0999
# 802  2022-01-18 00:00:00  0.0999
# 803  2022-01-19 00:00:00  0.0999
# 804  2022-01-20 00:00:00  0.0999

# %%
#df['date'] = pd.to_datetime(df['date'])
TimeSeries_LST2 =  list(df['NDVI'])   
TimeSeries_DATE2 = list(df['date'])
df = df.set_index('date')
df.tail()
# Out:
#               NDVI
# date
# 2022-01-16  0.0999
# 2022-01-17  0.0999
# 2022-01-18  0.0999
# 2022-01-19  0.0999
# 2022-01-20  0.0999

# %%
df.head()
# Out:
#              NDVI
# date
# 1984-04-15  0.087
# 1984-05-01  0.087
# 1984-05-17  0.087
# 1984-06-02  0.076
# 1984-06-18  0.083

# %%
import datetime
import time
from math import pi, atan2, cos, sin, sqrt
import matplotlib.pyplot as plt
import ee
import numpy as np
import scipy as sp
from scipy.interpolate import interp1d
import pandas as pd



#------------------------------------------------------------------------------#


def smooth(TS):
    N_TS = len(TS)
    
    N = 73
    #prepare the a and b coeficiants for the TFA
    Nharmonics = 3
    a = [0., 0., 0.]
    b = [0., 0., 0.]

    for t in range(N_TS):
        for p in range(Nharmonics):
            a[p] = a[p] + (2*TS[t]*cos(2*pi*(p+1)*(t+1)/N))
            b[p] = b[p] + (2*TS[t]*sin(2*pi*(p+1)*(t+1)/N))
            
    a = [a[i]/N_TS for i in range(len(a))] 
    b = [b[i]/N_TS for i in range(len(b))] 

    #prepare the first 3 harmonics of the TFA
    H0 = sum(TS) / N_TS
    TFA = [0. for j in range(N_TS)]
    H = [[0. for k in range(N_TS)] for i in range(Nharmonics)] 
    omega = [0. for j in range(Nharmonics)]   
    Phase = [0. for j in range(Nharmonics)]    
    Amplitude = [0. for j in range(Nharmonics)]
    
    for p in range(Nharmonics):
        omega[p] = 2. * pi * (p+1) / N
        Phase[p] = atan2( -b[p], a[p] )
        Amplitude[p] = sqrt( a[p]**2 + b[p]**2 )
        for t in range(N_TS):
            H[p][t] = Amplitude[p] * cos(omega[p]*(t+1) + Phase[p])

    for t in range(N_TS):
        TFA[t] = H0 + H[0][t] + H[1][t] + H[2][t]
    
    H1 = H[0][0:73]   
    H2 = H[1][0:73]   
    H3 = H[2][0:73]   
    return TFA, H0, Amplitude, Phase, H1, H2, H3

    


#we the data from ee  to 10 list of 46 point
chunks=[TimeSeries_LST2[x:x+46] for x in range(0, len(TimeSeries_LST2), 46)]
#we trun the list into a matrix arry in order to make avg vale for each day in a year
new = np.array(chunks)
print(new)
#we put no data vale on 1726.83 in order to deal with no data in the time series data from ee
#1726.83 is no data beacsoa 9999 * *0.02-273.15
noData = 1726.83
maskedvale = np.ma.masked_equal(new,noData)
print(maskedvale)
#we do mean on the matriex so we get in the end 46 point of data with no missing data
mean = maskedvale.mean(0)

#IN THIS PART WE MAKE THE interpolating TO 73 point in a time seirs  form 46 in the orginal data

N82 = range(1, 47)#range of 46 point 
y1 = mean
x = np.array(N82)
y = np.array(y1)

new_length = 73 #73 we set the range of the point we get from the interpolate to 73 
new_x = np.linspace(x.min(), x.max(), new_length)
new_y = sp.interpolate.interp1d(x, y, kind='cubic')(new_x)

n73fourier_vale = smooth(new_y)
LST_TFA       = n73fourier_vale[0]
LST_mean      = n73fourier_vale[1]
LST_Amplitude = n73fourier_vale[2]
LST_Phase     = n73fourier_vale[3]
H1            = n73fourier_vale[4]
H2            = n73fourier_vale[5]
H3            = n73fourier_vale[6]
print (LST_mean)
print (LST_Amplitude)
print (LST_Phase)
#we set the vale
#plot the vale after the fourier
#make range of a year

julian_date = range(0,365,5)
Ymean = np.full(73,LST_mean)
plt.plot(julian_date,new_y,'r',label='no fourier', linewidth=3)
plt.plot(julian_date,LST_TFA,'b',label='fourier',linewidth=2.8)
plt.plot(julian_date,Ymean)
plt.legend()
plt.show()

plt.plot(julian_date,H1+Ymean,'r',label='H1', linewidth=2)
plt.plot(julian_date,H2+Ymean,'b',label='H2', linewidth=2)
plt.plot(julian_date,H3+Ymean,'g',label='H3', linewidth=2)
# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,4))
plt.plot(df['NDVI'])
df.tail()
# Out:
#               NDVI
# date
# 2021-07-29  0.2990
# 2021-08-14  0.2450
# 2021-08-30  0.3130
# 2021-09-15  0.2880
# 2021-10-01  0.2665

# %%
#import matplotlib.pyplot as plt
#import pandas as pd
#import seaborn as sns
#from pandas.plotting import register_matplotlib_converters
#import statsmodels
#from statsmodels.tsa.seasonal import STL

#stl = STL(df,seasonal = 23, period =69)
#res = stl.fit()
#fig = res.plot()

# %%
#df['less_trend'] = df['NDVI'] - res.trend
#df.plot()

# %%
#df_less = df.drop(columns='NDVI')
#df_less.plot()
#print(len(df_less['less_trend']))
#df_less.head()

# %%
import statsmodels.api as sm
df['index'] = df.index
y = df['NDVI'].tolist()
x = df["index"].tolist()
n=len(df)
x = list(range(0,n))
lowess = sm.nonparametric.lowess(y, x, frac=.1)
lowess_x = list(zip(*lowess))[0]
lowess_y = list(zip(*lowess))[1]

plt.plot(lowess_x, lowess_y)

# %%
df['NDVI_lowess'] = lowess_y
#df_less = df_less.drop(columns='less_trend')
df['NDVI_lowess'].plot()
df['NDVI'].plot()

# %%
df['NDVI_less_trend'] = df['NDVI'] - df['NDVI_lowess']
y2 = df['NDVI_less_trend'].tolist()
x2 = df["index"].tolist()
n=len(df)
x2 = list(range(0,n))
lowess = sm.nonparametric.lowess(y2, x2, frac=.02)
lowess_x2 = list(zip(*lowess))[0]
lowess_y2 = list(zip(*lowess))[1]

plt.plot(lowess_x2, lowess_y2)

# %%
df['NDVI_less_trend'] = lowess_y2
df['NDVI_less_trend'].plot()

# %%
# Python3 code to demonstrate working of
# Convert date range to N equal durations
# Using loop
import datetime
  
# initializing dates
test_date1 = datetime.datetime(1984, 9, 9)
test_date2 = datetime.datetime(2021, 11, 18)
               
# printing original dates
print("The original date 1 is : " + str(test_date1))
print("The original date 2 is : " + str(test_date2))
  
# initializing N
#N = 460
#N = 730  
#N = 1460 #73*20 years
#N = 2920 #73*40 years
#N = 2628  #73*36 years
N = 2482 #73*34 years
temp = []
  
# getting diff.
diff = ( test_date2 - test_date1) // N
for idx in range(0, N):
      
    # computing new dates
    temp.append((test_date1 + idx * diff))
  
# using strftime to convert to userfriendly 
# format
res = []
for sub in temp:
  #res.append(sub.strftime("%Y/%m/%d %H:%M:%S"))
  res.append(sub.strftime("%Y/%m/%d"))
  
# printing result
print("N equal duration dates : " + str(res))
#https://www.ianwootten.co.uk/2014/07/01/splitting-a-date-range-in-python/
#https://miguendes.me/how-to-use-datetimetimedelta-in-python-with-examples
len(res)
# Out:
# The original date 1 is : 1984-09-09 00:00:00
# The original date 2 is : 2021-11-18 00:00:00
# N equal duration dates : ['1984/09/09', '1984/09/14', '1984/09/19', '1984/09/25', '1984/09/30', '1984/10/06', '1984/10/11', '1984/10/17', '1984/10/22', '1984/10/28', '1984/11/02', '1984/11/08', '1984/11/13', '1984/11/19', '1984/11/24', '1984/11/30', '1984/12/05', '1984/12/11', '1984/12/16', '1984/12/21', '1984/12/27', '1985/01/01', '1985/01/07', '1985/01/12', '1985/01/18', '1985/01/23', '1985/01/
11/24', '1987/11/29', '1987/12/05', '1987/12/10', '1987/12/16', '1987/12/21', '1987/12/27', '1988/01/01', '1988/01/07', '1988/01/12', '1988/01/17', '1988/01/23', '1988/01/28', '1988/02/03', '1988/02/08', '1988/02/14', '1988/02/19', '1988/02/25', '1988/03/01', '1988/03/07', '1988/03/12', '1988/03/18', '1988/03/23', '1988/03/29', '1988/04/03', '1988/04/09', '1988/04/14', '1988/04/19', '1988/04/25', '1988/04/30', '1988/05/06', '1988/05/11', '1988/05/17', '1988/05/22', '1988/05/28', '1988/06/02', '1988/06/08', '1988/06/13', '1988/06/19', '1988/06/24', '1988/06/30', '1988/07/05', '1988/07/11', '1988/07/16', '1988/07/22', '1988/07/27', '1988/08/01', '1988/08/07', '1988/08/12', '1988/08/18', '1988/08/23', '1988/08/29', '1988/09/03', '1988/09/09', '1988/09/14', '1988/09/20', '1988/09/25', '1988/10/01', '1988/10/06', '1988/10/12', '1988/10/17', '1988/10/23', '1988/10/28', '1988/11/03', '1988/11/08', '1988/11/13', '1988/11/19', '1988/11/24', '1988/11/30', '1988/12/05' ...
# 2482

# %%
date_list_for_N73 =[]
for date in res:
  
 date_list_for_N73.append(datetime.datetime.strptime(str(date[0:4])+str(date[5:7])+str(date[8:10]), '%Y%m%d'))

print(date_list_for_N73)
len(date_list_for_N73)
# Out:
# [datetime.datetime(1984, 9, 9, 0, 0), datetime.datetime(1984, 9, 14, 0, 0), datetime.datetime(1984, 9, 19, 0, 0), datetime.datetime(1984, 9, 25, 0, 0), datetime.datetime(1984, 9, 30, 0, 0), datetime.datetime(1984, 10, 6, 0, 0), datetime.datetime(1984, 10, 11, 0, 0), datetime.datetime(1984, 10, 17, 0, 0), datetime.datetime(1984, 10, 22, 0, 0), datetime.datetime(1984, 10, 28, 0, 0), datetime.datetime(1984, 11, 2, 0, 0), datetime.datetime(1984, 11, 8, 0, 0), datetime.datetime(1984, 11, 13, 0, 0), datetime.datetime(1984, 11, 19, 0, 0), datetime.datetime(1984, 11, 24, 0, 0), datetime.datetime(1984, 11, 30, 0, 0), datetime.datetime(1984, 12, 5, 0, 0), datetime.datetime(1984, 12, 11, 0, 0), datetime.datetime(1984, 12, 16, 0, 0), datetime.datetime(1984, 12, 21, 0, 0), datetime.datetime(1984, 12, 27, 0, 0), datetime.datetime(1985, 1, 1, 0, 0), datetime.datetime(1985, 1, 7, 0, 0), datetime.datetime(1985, 1, 12, 0, 0), datetime.datetime(1985, 1, 18, 0, 0), datetime.datetime(1985, 1, 23, 0, 0), datetime.datetime(1985, 1, 29, 0, 0), datetime.datetime(1985, 2, 3, 0, 0), datetime.datetime(1985, 2, 9, 0, 0), datetime.datetime(1985, 2, 14, 0, 0), datetime.datetime(1985, 2, 20, 0, 0), datetime.datetime(1985, 2, 25, 0, 0), datetime.datetime(1985, 3, 3, 0, 0), datetime.datetime(1985, 3, 8, 0, 0), datetime.datetime(1985, 3, 14, 0, 0), datetime.datetime(1985, 3, 19, 0, 0), datetime.datetime(1985, 3, 25, 0, 0), datetime.datetime(1985, 3, 30, 0, 0), datetime.datetime(1985, 4, 4, 0, 0), datetime.datetime(1985, 4, 10, 0, 0), datetime.datetime(1985, 4, 15, 0, 0), datetime.datetime(1985, 4, 21, 0, 0), datetime.datetime(1985, 4, 26, 0, 0), datetime.datetime(1985, 5, 2, 0, 0), datetime.datetime(1985, 5, 7, 0, 0), datetime.datetime(1985, 5, 13, 0, 0), datetime.datetime(1985, 5, 18, 0, 0), datetime.datetime(1985, 5, 24, 0, 0), datetime.datetime(1985, 5, 29, 0, 0), datetime.datetime(1985, 6, 4, 0, 0), datetime.datetime(1985, 6, 9, 0, 0), datetime.datetime(1985, 6, 15, 0, 0), datetime.datetime(1985, 6, 20, 0, 0), datetime.datetime(1985, 6, 26, 0, 0), datetime.datetime(1985, 7, 1, 0, 0), datetime.datetime(1985, 7, 7, 0, 0), datetime.datetime(1985, 7, 12, 0, 0), datetime.datetime(1985, 7, 17, 0, 0), datetime.datetime(1985, 7, 23, 0, 0), datetime.datetime(1985, 7, 28, 0, 0), datetime.datetime(1985, 8, 3, 0, 0), datetime.datetime(1985, 8, 8, 0, 0), datetime.datetime(1985, 8, 14, 0, 0), datetime.datetime(1985, 8, 19, 0, 0), datetime.datetime(1985, 8, 25, 0, 0), datetime.datetime(1985, 8, 30, 0, 0), datetime.datetime(1985, 9, 5, 0, 0), datetime.datetime(1985, 9, 10, 0, 0), datetime.datetime(1985, 9, 16, 0, 0), datetime.datetime(1985, 9, 21, 0, 0), datetime.datetime(1985, 9, 27, 0, 0), datetime.datetime(1985, 10, 2, 0, 0), datetime.datetime(1985, 10, 8, 0, 0), datetime.datetime(1985, 10, 13, 0, 0), datetime.datetime(1985, 10, 19, 0, 0), datetime.datetime(1985, 10, 24, 0, 0), datetime.datetime(1985, 10, 29, 0, 0), datetime.datetime(1985, 11, 4, 0, 0), datetime.datetime(1985, 11, 9, 0, 0), datetime.datetime(1985, 11, 15, 0, 0), datetime.datetime(1985, 11, 20, 0, 0), datetime.datetime(1985, 11, 26, 0, 0), datetime.datetime(1985, 12, 1, 0, 0), datetime.datetime(1985, 12, 7, 0, 0), datetime.datetime(1985, 12, 12, 0, 0), datetime.datetime(1985, 12, 18, 0, 0), datetime.datetime(1985, 12, 23, 0, 0), datetime.datetime(1985, 12, 29, 0, 0), datetime.datetime(1986, 1, 3, 0, 0), datetime.datetime(1986, 1, 9, 0, 0), datetime.datetime(1986, 1, 14, 0, 0), datetime.datetime(1986, 1, 20, 0, 0), datetime.datetime(1986, 1, 25, 0, 0), datetime.datetime(1986, 1, 30, 0, 0), datetime.datetime(1986, 2, 5, 0, 0), datetime.datetime(1986, 2, 10, 0, 0), datetime.datetime(1986, 2, 16, 0, 0), datetime.datetime(1986, 2, 21, 0, 0), datetime.datetime(1986, 2, 27, 0, 0), datetime.datetime(1986, 3, 4, 0, 0), datetime.datetime(1986, 3, 10, 0, 0), datetime.datetime(1986, 3, 15, 0, 0), datetime.datetime(1986, 3, 21, 0, 0), datetime.datetime(1986, 3, 26, 0, 0), datetime.datetime(1986, 4, 1, 0, 0), datetime ...
.08889290345869659, 0.0863901542585601, 0.06247314447003039, 0.053029751947527654, 0.04449602411718134, 0.036642915261409004, 0.029137385530870342, 0.02003871999429715, 0.009790291762120764, 0.008160065979749092, 0.008466112306528708, 0.00714763009849804, 0.005793729765426315, 0.0051360065403507444, 0.004724031749663944, 0.004239385141969271, 0.0036176751837554695, 0.0032270385441003184, 0.0036900248355049774, 0.004897505924947292, 0.006074384049298538, 0.006697089323703723, 0.005951987600854181, 0.004239989415769517, 0.002977386481584026, 0.002514679252157412, 0.00271229329229057, 0.0032100542070064024, 0.0034580907351812154, 0.003525038623963194, 0.004266862236452308, 0.005038333395737987, 0.004880627860102248, 0.0038355601771653163, 0.0018448918051090241, -0.0012099519598284523, -0.005192438855626554, -0.009533143109355956, -0.013465422386825493, -0.01671649066055713, -0.01923169566819561, -0.02087939722693043, -0.021987482071477743, -0.02277662737266613, -0.023080785934143505, -0.02278016443625699, -0.022015388501877856, -0.021154905046174084, -0.0204963370608 ...
# 782

# %%
import math
to_forier = list(df['NDVI_less_trend'])
for i in to_forier:
  if math.isnan(i) == True:
    to_forier[i] = 0.04409690393354137
  else:
    continue 


#we the data from ee  to 10 list of 46 point
chunks=[to_forier[x:x+46] for x in range(0, len(to_forier), 46)]
#we trun the list into a matrix arry in order to make avg vale for each day in a year
new = np.array(chunks)
#we put no data vale on 1726.83 in order to deal with no data in the time series data from ee
#1726.83 is no data beacsoa 9999 * *0.02-273.15
noData = 1726.83
maskedvale = np.ma.masked_equal(new,noData)
#we do mean on the matriex so we get in the end 46 point of data with no missing data
mean = maskedvale.mean(0)

#IN THIS PART WE MAKE THE interpolating TO 73 point in a time seirs  form 46 in the orginal data

N46 = range(1, 47)#range of 46 point 
y1 = mean
x = np.array(N46)
y = np.array(y1)

new_length = 73 #73 we set the range of the point we get from the interpolate to 73 
new_x = np.linspace(x.min(), x.max(), new_length)
new_y = sp.interpolate.interp1d(x, y, kind='cubic')(new_x)

n73fourier_vale = smooth(new_y)
LST_TFA       = n73fourier_vale[0]
print(LST_TFA)
# Out:
# [0.0015222547154501369, 0.0006043602480469346, -0.0001348131674826109, -0.000646691786791863, -0.0008909203701990564, -0.0008375313055618075, -0.0004686733161470939, 0.00022020230614550962, 0.0012197720098635085, 0.0025069281700872475, 0.004045530939619083, 0.0057877933089059315, 0.007676234147120723, 0.009646102788271034, 0.01162815295580814, 0.01355162503002084, 0.015347284967694864, 0.01695036619655422, 0.01830326760378071, 0.019357875853433164, 0.020077402727238142, 0.020437656566588278, 0.020427699426637004, 0.02004987622293935, 0.019319236834079583, 0.018262404722774454, 0.01691597421448668, 0.01532454146885487, 0.013538490121191502, 0.011611660745870934, 0.009599033395297548, 0.007554544712967803, 0.005529146222710139, 0.003569189521018504, 0.001715198772497779, 1.0629158526377852e-06, -0.0015463487469215258, -0.0029071714510048906, -0.004068178777452341, -0.005022133764541741, -0.005766939894955244, -0.006304682107848684, -0.00664064862285246, -0.006782418216277041, -0.0
985, 0.007315255682561284, 0.005807925797573003, 0.004314251069983953, 0.0028640066782541877, 0.0014852953353057642, 0.00020402383923145983, -0.0009565956389636365, -0.001976517186615734, -0.002839300372385862, -0.003532508378267015, -0.004048053017404359, -0.004382471691298854, -0.004537119219608009, -0.00451825649582682, -0.004337018343965341, -0.0040092449369134135, -0.003555164732756899, -0.0029989220130995937, -0.002367948566038067, -0.0016921865300547926, -0.0010031774912179676, -0.00033304112035020236, 0.00028662557631666815, 0.0008258904724941405, 0.0012576266790917156, 0.0015586041987923377, 0.0017104847403678794, 0.001700672712471099, 0.0015229791067472597, 0.0011780611349093114, 0.000673608884518751, 2.426054185294187e-05, -0.0007487605885126673, -0.0016182815426301809, -0.0025520692492383736, -0.0035139436390898495, -0.004465072798035013, -0.005365399455786361, -0.006175141211578161, -0.006856302710528469, -0.007374136753753317, -0.007698493142381116, -0.00780499884332098, -0.007676020581117768, -0.00730137081288176, -0.006678729711672995, -0.005813768650168638, -0.0047199740623820015, -0.003418183767031974, -0.0019358601820834748, -0.00030613572529211935, 0.0014333254460030397, 0.0032415987538101953, 0.005075849193862653, 0.006892704609471659, 0.008649598546588729, 0.010306033190175916, 0.011824719236450806, 0.01317255761160027, 0.014321437171740418, 0.015248832334341073, 0.01593819441488176, 0.01637913972144824, 0.016567445705790232, 0.01650487328637859, 0.016198838566216664,  ...

# %%
print(len(LST_TFA_34_Y))
print(len(date_list_for_N73))
print(len(LST_TFA))
# Out:
# 2482
# 2482
# 73

# %%
# dictionary of lists 
dict = {'DATE': date_list_for_N73, 'NDVI': LST_TFA_34_Y, } 
    
df_f = pd.DataFrame(dict)
df_f['DATE'] = pd.to_datetime(df_f['DATE'])

df_f.set_index('DATE', inplace=True) 
df_f = df_f.resample('16D').mean() 
df_f = df_f[:782]
plt.figure(figsize=(12,4))
plt.plot(df_f)
#df_less_smooth.plot()

# %%
print(len(df))
print(len(df_f))
df.head()
# Out:
# 782
# 782
#              NDVI      index  NDVI_lowess  NDVI_less_trend
# date
# 1984-09-09  0.078 1984-09-09     0.087589        -0.012952
# 1984-09-25  0.082 1984-09-25     0.088603        -0.012564
# 1984-10-11  0.086 1984-10-11     0.089609        -0.012019
# 1984-10-27  0.066 1984-10-27     0.090607        -0.011332
# 1984-11-12  0.071 1984-11-12     0.091595        -0.010560

# %%
pd.set_option('display.max_rows', None)
df['fourier'] = df_f['NDVI']
k=0
for i in df['NDVI']:
  df['fourier'][k] = df_f['NDVI'][k]
  k+=1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
import matplotlib
matplotlib.pyplot.plot(df['NDVI_less_trend'])
matplotlib.pyplot.plot(df['fourier'],color='red')
matplotlib.pyplot.show()

# %%
import matplotlib.pyplot as plt
from datetime import datetime
df['area'] = df['NDVI_less_trend'] - df['fourier']
plt.figure(figsize=(10,4))
plt.plot(df['area'])
for year in range(1984,2022):
  plt.axvline(datetime(year,10,1), color='k', linestyle='--', alpha=0.5)

# %%
k=0
for i in df['area']:
  if i<=0 :
    df['area'][k]=0
    k+=1  
  elif i>0:
    k+=1
    
plt.figure(figsize=(14,4))
plt.plot(df['area'])
for year in range(1984,2022):
  plt.axvline(datetime(year,10,1), color='k', linestyle='--', alpha=0.5)
plt.suptitle('Rooibank - NDVI',fontsize=20) 
plt.xlabel("year",fontsize=12)
plt.ylabel("NDVI",fontsize=12)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# Text(0, 0.5, 'NDVI')

# %%
from scipy.integrate import simps
import numpy as np
dict_integrate = {}
for year in range(1984,2009):
  slice = df['area'][(datetime(year,10,1)):(datetime(year+1,10,1))]
  y = np.array(slice)
  I = simps(y,dx=12)
  dict_integrate[(year+1)] = I

for year in range(2013,2021):
  slice = df['area'][(datetime(year,10,1)):(datetime(year+1,10,1))]
  y = np.array(slice)
  I = simps(y,dx=12)
  dict_integrate[(year+1)] = I
  print((I))
# Out:
# 1.8451458149321631
# 0.26084005880865835
# 0.31276315210632244
# 0.014751151271753516
# 3.111474365426562
# 0.17752368462782314
# 0.6329759740707592
# 0.8120906057941979

# %%
x = list(dict_integrate.keys())
print(x)
y = list(dict_integrate.values())
print (y)
# Out:
# [1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# [0.7423352473875273, 1.471835805339817, 0.7064700140093154, 0.4415568350256609, 14.093785626821706, 15.488925842631346, 0.8007572735889225, 0.43506876530018684, 2.641930049074349, 1.1681916454979677, 0.5428573389262147, 0.0015495465557698457, 12.96044210239028, 1.8490660490542918, 0.0, 2.0018453649261523, 3.395151511597515, 0.013853236122744042, 0.21645856833935861, 0.4383794501276081, 2.062093675362519, 2.4833898647428074, 0.3527215923185869, 0.5007025902916854, 4.757771367224104, 1.8451458149321631, 0.26084005880865835, 0.31276315210632244, 0.014751151271753516, 3.111474365426562, 0.17752368462782314, 0.6329759740707592, 0.8120906057941979]

# %%
df_integrate = pd.DataFrame()
df_integrate['year'] = list(dict_integrate.keys())
df_integrate['area'] = list(dict_integrate.values())
dev = df_integrate['area'].std()
df_integrate['std'] = 0.56

k=0
for i in df_integrate['area']:
  df_integrate['std'][k] = (i/dev)
  k+=1

x = list(dict_integrate.keys())
y = list(dict_integrate.values())
y2 = list(df_integrate['std'])


fig, ax = plt.subplots(figsize=(12,8))

ax.fill_between(range(1984,2022), dev, facecolor = "purple", alpha=0.4, linestyle='--', linewidth=2)
ax.fill_between(range(1984,2022), dev*2, facecolor = "purple", alpha=0.3, linestyle='--', linewidth=2)
ax.fill_between(range(1984,2022), dev*3, facecolor = "purple", alpha=0.2, linestyle='--', linewidth=2)

ax.scatter(x, y, color = 'black')
ax.set_xlabel("year",fontsize=14)
ax.set_ylabel("Area", fontsize=14)
ax2=ax.twinx()
# make a plot with different y-axis using second axis object
ax2.plot(x, y2 ,color="blue" )
ax2.set_ylabel("std (\u03C3)",color="blue",fontsize=14)
fig.suptitle('LANDSAT - Rooibank',fontsize=20)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# Text(0.5, 0.98, 'LANDSAT - Rooibank')

# %%
#downloading the df_integrate
from google.colab import files
df_integrate.to_csv('roi_land_fourier.csv') 
files.download('roi_land_fourier.csv')
